# %% [markdown]
# # Nidhay Pancholi
# # LetsGrowMore internship
# # Task 2

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier,plot_tree
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
d={'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2}
df['Species'].replace(d,inplace=True)

# %%
df.drop('Id',axis=1,inplace=True)
X=df.drop('Species',axis=1)
y=df['Species']

# %%
sns.scatterplot(data=X,x='PetalLengthCm',y='PetalWidthCm',hue=y)
plt.show()

# %%
sns.scatterplot(data=X,x='SepalLengthCm',y='SepalWidthCm',hue=y)
plt.show()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)
model=DecisionTreeClassifier(max_depth=3)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_train_pred=model.predict(X_train)
accuracy_score(y_train,y_train_pred)
# Out:
# 0.9642857142857143

# %%
y_pred=model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9473684210526315

# %%
X.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
fig = plt.figure(figsize=(25,20))
plot_tree(model,feature_names=X.columns,  
                   class_names=list(d.keys()),
                   filled=True)
# Out:
# [Text(523.125, 951.3000000000001, 'PetalLengthCm <= 2.45\ngini = 0.665\nsamples = 112\nvalue = [38, 34, 40]\nclass = Iris-virginica'),
#  Text(348.75, 679.5, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]\nclass = Iris-setosa'),
#  Text(697.5, 679.5, 'PetalLengthCm <= 4.75\ngini = 0.497\nsamples = 74\nvalue = [0, 34, 40]\nclass = Iris-virginica'),
#  Text(348.75, 407.70000000000005, 'PetalWidthCm <= 1.65\ngini = 0.062\nsamples = 31\nvalue = [0, 30, 1]\nclass = Iris-versicolor'),
#  Text(174.375, 135.89999999999998, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]\nclass = Iris-versicolor'),
#  Text(523.125, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-virginica'),
#  Text(1046.25, 407.70000000000005, 'PetalLengthCm <= 5.05\ngini = 0.169\nsamples = 43\nvalue = [0, 4, 39]\nclass = Iris-virginica'),
#  Text(871.875, 135.89999999999998, 'gini = 0.444\nsamples = 12\nvalue = [0, 4, 8]\nclass = Iris-virginica'),
#  Text(1220.625, 135.89999999999998, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]\nclass = Iris-virginica')]
